# %% [markdown]
# # Task 1: EDA — Heart Disease Dataset
#
# TODO: load data/processed/heart_cleaned.csv, required plots (class balance, histograms, correlation heatmap) + your own plots, with a written observation under each.
